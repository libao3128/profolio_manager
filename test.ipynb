# %%
import pandas as pd
from portfolio import Portfolio

portfolio = Portfolio('Firstrade')
portfolio.from_csv('data/FT_CSV_87701987.csv')

# %%
portfolio.principal_value
# Out:
# 2022-01-25    3500.0
# 2022-01-26    3500.0
# 2022-01-27    3500.0
# 2022-01-28    3500.0
# 2022-01-31    3500.0
#                ...
# 2023-03-27    9975.0
# 2023-03-28    9975.0
# 2023-03-29    9975.0
# 2023-03-30    9975.0
# 2023-03-31    9975.0
# Name: Amount, Length: 298, dtype: float64

# %%
# Out:
# Successfully connected to SQLite database
# 2022-01-25    1.000000
# 2022-01-26    0.995126
# 2022-01-27    0.995629
# 2022-01-28    1.002911
# 2022-01-31    0.867577
#                 ...
# 2023-03-27    0.977325
# 2023-03-28    0.969217
# 2023-03-29    0.991197
# 2023-03-30    0.999789
# 2023-03-31    1.020382
# Length: 298, dtype: float64

# %%
pd.Series(portfolio.position_value['total'])+portfolio.margin_balance['Amount']
# Out:
# Successfully connected to SQLite database
# 2022-01-25        0.000000
# 2022-01-26      751.029999
# 2022-01-27     1140.400024
# 2022-01-28     1480.379982
# 2022-01-31     2126.010025
#                   ...
# 2023-03-27    12370.527895
# 2023-03-28    12289.657919
# 2023-03-29    12508.908013
# 2023-03-30    12594.607991
# 2023-03-31    12800.028031
# Freq: B, Length: 309, dtype: float64

# %%
data = pd.read_csv('data\FT_CSV_87701987.csv')
new_data = pd.read_csv('data\FT_CSV_87701987.csv')
data=  pd.concat([data, new_data])
data.drop_duplicates()
# Out:
#            Symbol  Quantity     Price    Action  \
# 0                       0.0       NaN     Other
# 1    MSFT               1.0  302.4681       BUY
# 2    FB                 1.0  302.4100       BUY
# 3    AAPL               1.0  163.2100       BUY
# 4    NFLX               1.0  387.6117       BUY
# ..            ...       ...       ...       ...
# 421  UBER               5.0   30.5000       BUY
# 422  TSLA               2.0  181.4257       BUY
# 423  BAC               10.0   29.5372       BUY
# 424  GTLB              -5.0   32.7338      SELL
# 425  HSY                0.0       NaN  Dividend
#
#                                            Description   TradeDate  \
# 0    Wire Funds Received            FedRef 20220125...  2022-01-25
# 1    MICROSOFT CORP                 UNSOLICITED    ...  2022-01-26
# 2    META PLATFORMS INC             CLASS A COMMON ...  2022-01-26
# 3    APPLE INC                      UNSOLICITED    ...  2022-01-26
# ...

# %%
str(['date','ticker']+['adj_close'])
# Out:
# "['date', 'ticker', 'adj_close']"
